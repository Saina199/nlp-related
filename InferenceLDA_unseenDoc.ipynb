# %%
import InferenceLDA
import pandas as pd

# %%
dat = pd.read_csv('./data/testData.csv')
text = dat['text'][9005:9006].values[0]

# %%
InferenceLDA.inference(text,'./ModelNoun38')
# Out:
# (([(2, 0.014544539),
#    (8, 0.14795165),
#    (12, 0.13311929),
#    (14, 0.012252414),
#    (22, 0.112715125),
#    (24, 0.24385087),
#    (25, 0.056595743),
#    (26, 0.050262842),
#    (34, 0.19374976)],
#   [(28, [24, 2]),
#    (58, [8, 34, 22, 24]),
#    (62, [8]),
#    (65, [22, 8, 12, 25]),
#    (112, [22, 34]),
#    (137, [24, 25]),
#    (156, [34]),
#    (171, [24, 34, 25, 26]),
#    (177, [24, 26]),
#    (216, [24, 25, 34, 8]),
#    (228, [24, 25]),
#    (229, [24, 8, 25, 22]),
#    (233, [24, 25]),
#    (235, [24, 25, 34]),
#    (238, [24, 8, 25, 34, 22]),
#    (451, [24, 8, 22, 26, 34, 12, 25]),
#    (654, [8, 34, 22, 24]),
#    (739, [34, 22, 8, 2]),
#    (814, [24, 8, 34, 14, 26]),
#    (867, [24, 8, 25]),
#    (881, [8, 24, 2]),
#    (971, [8, 24]),
#    (1170, [24, 8, 25, 22]),
#    (1249, [22, 24, 25]),
#    (1287, [8, 24, 25, 22]),
#    (1453, [34]),
#    (1477, [24, 8, 22]),
#    (1576, [8, 24, 25]),
#    (2087, [34]),
#    (2115, [22]),
# ...
